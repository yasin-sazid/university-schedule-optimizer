# %% [markdown]
# <a href="https://colab.research.google.com/github/yasin-sazid/university-schedule-optimizer/blob/main/university_scheduling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.14.6206-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting absl-py>=2.0.0 (from ortools)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from ortools) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ortools) (2.2.2)
# Collecting protobuf<6.32,>=6.31.1 (from ortools)
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from ortools) (4.14.1)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from ortools) (4.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->ortools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->ortools) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.17.0)
# Downloading ortools-9.14.6206-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (27.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.7/27.7 MB 59.3 MB/s eta 0:00:00
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 8.6 MB/s eta 0:00:00
# Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 15.7 MB/s eta 0:00:00
# Installing collected packages: protobuf, absl-py, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.31.1 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.31.1 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.31.1 which is incompatible.
# Successfully installed absl-py-2.3.1 ortools-9.14.6206 protobuf-6.31.1

# %%
from ortools.sat.python import cp_model
import pandas as pd

# Track all penalties to minimize
penalty_vars = []
penalty_weights = []  # Optional: can assign different weights to room vs time

# Load Excel files
classrooms_df = pd.read_excel("data.xlsx", sheet_name="classrooms")
slots_df = pd.read_excel("data.xlsx", sheet_name="slots")
schedule_df = pd.read_excel("sample_schedule.xlsx", sheet_name="Sheet1")

# Step 1: Clean and tag schedule data
valid_schedule = schedule_df[schedule_df['Course'].notna() & schedule_df['Instructor'].notna()].copy()
valid_schedule['CourseID'] = valid_schedule['Course'].astype(str) + "_" + valid_schedule['Section'].astype(str)
valid_schedule['IsLab'] = valid_schedule['Course'].str.contains(r'Lab', case=False, na=False)

valid_schedule['Time From'] = pd.to_datetime(valid_schedule['Time From']).dt.strftime("%H:%M:%S")
valid_schedule['Time To']   = pd.to_datetime(valid_schedule['Time To']).dt.strftime("%H:%M:%S")

# Step 1.5: Expand Weekday column into list of days
def expand_days(day_str):
    return list(day_str.strip()) if isinstance(day_str, str) else []

valid_schedule['Days'] = valid_schedule['Weekday'].apply(expand_days)
valid_schedule['NumDays'] = valid_schedule['Days'].apply(len)

# Load designation sheet (last sheet)
designations_df = pd.read_excel("data.xlsx", sheet_name="faculties")  # last sheet
designations_df.columns = designations_df.columns.str.strip().str.lower()

# Assuming columns are like: 'initial', 'designation'
# Normalize column names
designations_df.rename(columns={'initial': 'Instructor', 'designation': 'Designation'}, inplace=True)

# Merge with valid_schedule
valid_schedule = valid_schedule.merge(designations_df, on='Instructor', how='left')

valid_schedule = valid_schedule.loc[:, ~valid_schedule.columns.str.contains('^Unnamed')]

print(valid_schedule.head(50))

# Room and time slot encoding
room_list = classrooms_df['Room'].dropna().unique().tolist()
room_index = {room: idx for idx, room in enumerate(room_list)}
room_type_map = dict(zip(classrooms_df['Room'], classrooms_df['Theory/Lab']))
room_size_map = dict(zip(classrooms_df['Room'], classrooms_df['Size']))

slots_df['TimeSlot'] = (
    slots_df['Time From'].astype(str) + "-" +
    slots_df['Time To'].astype(str) + "-" +
    slots_df['Weekday']
)

print(slots_df.groupby(['Weekday', 'SlotType']).size())

timeslot_list = slots_df['TimeSlot'].unique().tolist()
timeslot_index = {slot: idx for idx, slot in enumerate(timeslot_list)}
slot_types = slots_df['SlotType'].tolist()

print("\n🧾 Course Summary:")
for _, row in valid_schedule.iterrows():
    print(f"• {row['CourseID']}: Days={row['Days']}, IsLab={row['IsLab']}, Size={row['Size']}, Instructor={row['Instructor']}")

# Step 2: Create variables
model = cp_model.CpModel()
room_vars = {}
timeslot_vars = {}

for _, row in valid_schedule.iterrows():
    cid = row['CourseID']
    days = row['Days']

    room_vars[cid] = model.NewIntVar(0, len(room_list) - 1, f"room_{cid}")
    timeslot_vars[cid] = [
        model.NewIntVar(0, len(timeslot_list) - 1, f"time_{cid}_{d}")
        for d in days
    ]

# Step 3: Time slot filtering based on type and day
from datetime import datetime

# Map timeslot index to its day and slot type
slot_info = {
    idx: {
        'day': ts.split('-')[-1],
        'slot_type': slots_df.iloc[idx]['SlotType']
    }
    for idx, ts in enumerate(timeslot_list)
}

# Step 3: Timeslot must match correct day and slot type

from datetime import datetime, timedelta

def parse_time_duration(t_from, t_to):
    try:
        t1 = pd.to_datetime(t_from).time()
        t2 = pd.to_datetime(t_to).time()

        start = datetime.combine(datetime.today(), t1)
        end = datetime.combine(datetime.today(), t2)

        # If end is earlier, it's probably PM (Excel time logic)
        if end <= start:
            end = datetime.combine(datetime.today(), t2) + timedelta(hours=12)

        duration = (end - start).seconds / 3600
        return duration
    except Exception as e:
        print(f"❌ Failed to parse duration from {t_from} to {t_to}: {e}")
        return 0

from datetime import datetime

slot_info = {
    idx: {
        'day': ts.split('-')[-1],
        'slot_type': slots_df.iloc[idx]['SlotType']
    }
    for idx, ts in enumerate(timeslot_list)
}

for _, row in valid_schedule.iterrows():
    cid = row['CourseID']
    days = row['Days']
    is_lab = row['IsLab']
    time_from = str(row['Time From']).strip()
    time_to = str(row['Time To']).strip()

    try:
        duration_hours = parse_time_duration(time_from, time_to)
    except:
        duration_hours = 0

    for i, d in enumerate(days):
        allowed_types = []

        if is_lab:
            if 2.8 <= duration_hours <= 3.2:
                allowed_types = ['Lab-3hr']
            elif 1.7 <= duration_hours <= 2.3:
                allowed_types = ['Lab-2hr']
            elif 1.3 <= duration_hours <= 1.7:
                allowed_types = ['Theory']
        else:
            allowed_types = ['Theory']

        valid_indices = [
            idx for idx, info in slot_info.items()
            if info['day'] == d and info['slot_type'] in allowed_types
        ]

        if not valid_indices:
            print(f"⚠️ Fallback: No matching slot for {cid} on {d} (duration={duration_hours:.2f}h), relaxing...")
            valid_indices = [
                idx for idx, info in slot_info.items()
                if info['day'] == d
            ]

        model.AddAllowedAssignments([timeslot_vars[cid][i]], [[j] for j in valid_indices])

#Step 3.5: Preference by Designation
for _, row in valid_schedule.iterrows():
    designation = str(row.get('Designation', '')).lower()
    if designation.strip().lower() in ['professor', 'dean', 'head']:
        cid = row['CourseID']
        preferred_room = row['Room']
        time_from = row['Time From']
        time_to = row['Time To']
        days = row['Days']

        # Room match penalty (strong soft constraint)
        if preferred_room in room_index:
            room_match = model.NewBoolVar(f"room_forced_{cid}")
            model.Add(room_vars[cid] == room_index[preferred_room]).OnlyEnforceIf(room_match)
            model.Add(room_vars[cid] != room_index[preferred_room]).OnlyEnforceIf(room_match.Not())
            # penalty_vars.append(room_match.Not())
            # penalty_weights.append(100)  # high penalty
            penalty_vars.append((room_match.Not(), f"Room fixed for {cid} (Prof/Dean/Head)"))
            penalty_weights.append(100)

        # Timeslot match penalties (per day)
        for i, d in enumerate(days):
            matching_slot = f"{time_from}-{time_to}-{d}"
            if matching_slot in timeslot_index:
                t_match = model.NewBoolVar(f"timeslot_forced_{cid}_{d}")
                model.Add(timeslot_vars[cid][i] == timeslot_index[matching_slot]).OnlyEnforceIf(t_match)
                model.Add(timeslot_vars[cid][i] != timeslot_index[matching_slot]).OnlyEnforceIf(t_match.Not())
                # penalty_vars.append(t_match.Not())
                # penalty_weights.append(100)  # strong soft constraint
                penalty_vars.append((t_match.Not(), f"Time fixed for {cid} (Prof/Dean/Head)"))
                penalty_weights.append(100)
            else:
                print(f"⚠️ Slot {matching_slot} not found for {cid}")

    # Preference by Adjunct Faculty
    if 'adjunct' in designation:
        cid = row['CourseID']
        time_from = row['Time From']
        time_to = row['Time To']
        days = row['Days']

        # Timeslot match penalties (per day)
        for i, d in enumerate(days):
            matching_slot = f"{time_from}-{time_to}-{d}"
            if matching_slot in timeslot_index:
                t_match = model.NewBoolVar(f"adjunct_time_pref_{cid}_{d}")
                model.Add(timeslot_vars[cid][i] == timeslot_index[matching_slot]).OnlyEnforceIf(t_match)
                model.Add(timeslot_vars[cid][i] != timeslot_index[matching_slot]).OnlyEnforceIf(t_match.Not())
                # penalty_vars.append(t_match.Not())
                # penalty_weights.append(100)  # medium-high weight for adjunct faculty
                penalty_vars.append((t_match.Not(), f"Time preference for Adjunct {cid}"))
                penalty_weights.append(100)
            else:
                print(f"⚠️ Slot {matching_slot} not found for Adjunct {cid}")

    # Time preference for remaining faculty members
    is_special = any(key in designation for key in ['professor', 'dean', 'head', 'adjunct'])

    if not is_special:
        cid = row['CourseID']
        time_from = row['Time From']
        time_to = row['Time To']
        days = row['Days']

        for i, d in enumerate(days):
            matching_slot = f"{time_from}-{time_to}-{d}"
            if matching_slot in timeslot_index:
                t_match = model.NewBoolVar(f"pref_time_basic_{cid}_{d}")
                model.Add(timeslot_vars[cid][i] == timeslot_index[matching_slot]).OnlyEnforceIf(t_match)
                model.Add(timeslot_vars[cid][i] != timeslot_index[matching_slot]).OnlyEnforceIf(t_match.Not())

                # Assign low weight (e.g., 20) for basic time preference
                penalty_vars.append((t_match.Not(), f"Basic time preference mismatch for {cid}"))
                penalty_weights.append(20)
            else:
                print(f"⚠️ No exact preferred time match for general faculty {cid} on {d}")

# Step 3.5.3: Main Building preference for Senior Faculties
for _, row in valid_schedule.iterrows():
    cid = row['CourseID']
    designation = str(row.get('Designation', '')).lower()

    if any(key in designation for key in ['professor', 'associate', 'adjunct']):
        # Preferred building is "Main"
        preferred_building = "Main"
        preferred_rooms = [
            r for r in room_list
            if str(classrooms_df[classrooms_df['Room'] == r]['Building'].values[0]).strip().lower() == preferred_building.lower()
        ]

        if preferred_rooms:
            valid_room_indices = [room_index[r] for r in preferred_rooms]
            building_match = model.NewBoolVar(f"building_pref_{cid}")
            model.AddAllowedAssignments([room_vars[cid]], [[i] for i in valid_room_indices]).OnlyEnforceIf(building_match)
            model.AddForbiddenAssignments([room_vars[cid]], [[i] for i in valid_room_indices]).OnlyEnforceIf(building_match.Not())
            # penalty_vars.append(building_match.Not())
            # penalty_weights.append(80)  # Soft penalty weight between #1 (100) and #2 (90)
            penalty_vars.append((building_match.Not(), f"Main Building preference for {cid}"))
            penalty_weights.append(80)

# Step 3.5.4: Building preference constraint (FUB/AB1/AB3) for certain faculty offices
# Uses: room_vars, room_index, room_building_map, valid_schedule['Building']
# Normalize building preference
preferred_buildings = ['FUB', 'AB1', 'AB3']
room_building_map = dict(zip(classrooms_df['Room'], classrooms_df['Building']))

# Map room → index
for _, row in valid_schedule.iterrows():
    cid = row['CourseID']
    instructor_building = str(row.get('Building', '')).strip().upper()

    if instructor_building in preferred_buildings:
        # Filter rooms in same building
        preferred_room_indices = [
            idx for room, idx in room_index.items()
            if room_building_map.get(room, '').strip().upper() == instructor_building
        ]

        if preferred_room_indices:
            # Add soft penalty for violating preferred building
            room_match = model.NewBoolVar(f"room_building_match_{cid}")
            model.AddAllowedAssignments([room_vars[cid]], [[r] for r in preferred_room_indices]).OnlyEnforceIf(room_match)
            model.AddForbiddenAssignments([room_vars[cid]], [[r] for r in preferred_room_indices]).OnlyEnforceIf(room_match.Not())
            # penalty_vars.append(room_match.Not())  # 1 if not matched
            # penalty_weights.append(60)  # Medium priority soft constraint
            penalty_vars.append((room_match.Not(), f"Faculty office building preference for {cid}"))
            penalty_weights.append(60)

# Step 3.5.5: Back-to-back classes → Prefer same building for faculty
from datetime import datetime

print("\n🏃 Back-to-back same building constraint:")
time_format = "%H:%M:%S"

# Parse timeslot start-end for each index
timeslot_time_map = {}
for idx, slot in enumerate(timeslot_list):
    start, end, day = slot.split("-")
    timeslot_time_map[idx] = {
        "day": day,
        "start": datetime.strptime(start, time_format),
        "end": datetime.strptime(end, time_format)
    }

# Group course IDs by instructor
instructor_courses = valid_schedule.groupby("Instructor")["CourseID"].apply(list).to_dict()

for instructor, cids in instructor_courses.items():
    for d in ['S', 'M', 'T', 'W', 'R']:
        # Gather all (cid, day_index, slot_var) tuples for this instructor on day d
        day_slots = []
        for cid in cids:
            row = valid_schedule[valid_schedule["CourseID"] == cid]
            if row.empty:
                continue
            days = row.iloc[0]['Days']
            for i, day_code in enumerate(days):
                if day_code == d:
                    day_slots.append((cid, i, timeslot_vars[cid][i]))

        # Compare each pair for back-to-back same-day classes
        for i in range(len(day_slots)):
            cid1, i1, slot_var1 = day_slots[i]
            for j in range(i + 1, len(day_slots)):
                cid2, i2, slot_var2 = day_slots[j]

                for idx1 in range(len(timeslot_list)):
                    info1 = timeslot_time_map[idx1]
                    if info1["day"] != d:
                        continue
                    for idx2 in range(len(timeslot_list)):
                        info2 = timeslot_time_map[idx2]
                        if info2["day"] != d:
                            continue
                        # Check if classes are back-to-back (<=10 min gap)
                        gap1 = (info2["start"] - info1["end"]).total_seconds() / 60
                        gap2 = (info1["start"] - info2["end"]).total_seconds() / 60
                        if 0 <= gap1 <= 10 or 0 <= gap2 <= 10:
                            # If both slots assigned, enforce same building
                            cond1 = model.NewBoolVar(f"cid1_match_{cid1}_{cid2}_{d}")
                            cond2 = model.NewBoolVar(f"cid2_match_{cid1}_{cid2}_{d}")
                            both = model.NewBoolVar(f"both_{cid1}_{cid2}_{d}")

                            model.Add(slot_var1 == idx1).OnlyEnforceIf(cond1)
                            model.Add(slot_var1 != idx1).OnlyEnforceIf(cond1.Not())
                            model.Add(slot_var2 == idx2).OnlyEnforceIf(cond2)
                            model.Add(slot_var2 != idx2).OnlyEnforceIf(cond2.Not())
                            model.AddBoolAnd([cond1, cond2]).OnlyEnforceIf(both)
                            model.AddBoolOr([cond1.Not(), cond2.Not()]).OnlyEnforceIf(both.Not())

                            # Violation if buildings not equal
                            building_mismatch = model.NewBoolVar(f"building_mismatch_{cid1}_{cid2}_{d}")
                            model.Add(room_vars[cid1] != room_vars[cid2]).OnlyEnforceIf(building_mismatch)
                            model.Add(room_vars[cid1] == room_vars[cid2]).OnlyEnforceIf(building_mismatch.Not())

                            # Penalty if both are back-to-back AND building mismatch
                            violation = model.NewBoolVar(f"bb_violation_{cid1}_{cid2}_{d}")
                            model.AddBoolAnd([both, building_mismatch]).OnlyEnforceIf(violation)
                            model.AddBoolOr([both.Not(), building_mismatch.Not()]).OnlyEnforceIf(violation.Not())

                            # penalty_vars.append(violation)
                            # penalty_weights.append(70)
                            penalty_vars.append((violation, f"Back-to-back building mismatch: {cid1} & {cid2} on {d}"))
                            penalty_weights.append(70)

# Step 3.5.6: Idle Time Constraints
print("\n🕒 Idle Time Constraints:")

from datetime import datetime

time_format = "%H:%M:%S"
weekly_idle = {}

for instructor, cids in instructor_courses.items():
    for d in ['S', 'M', 'T', 'W', 'R']:
        slot_vars = []
        for cid in cids:
            row = valid_schedule[valid_schedule["CourseID"] == cid]
            if row.empty:
                continue
            days = row.iloc[0]['Days']
            for i, day_code in enumerate(days):
                if day_code == d:
                    slot_vars.append(timeslot_vars[cid][i])

        if len(slot_vars) < 2:
            continue  # No idle time possible

        earliest = model.NewIntVar(0, len(timeslot_list) - 1, f"{instructor}_{d}_first")
        latest   = model.NewIntVar(0, len(timeslot_list) - 1, f"{instructor}_{d}_last")

        model.AddMinEquality(earliest, slot_vars)
        model.AddMaxEquality(latest, slot_vars)

        # Get start/end minutes for each slot
        start_minutes = [int(datetime.strptime(slot.split("-")[0], time_format).hour) * 60 +
                         int(datetime.strptime(slot.split("-")[0], time_format).minute)
                         for slot in timeslot_list]
        end_minutes = [int(datetime.strptime(slot.split("-")[1], time_format).hour) * 60 +
                       int(datetime.strptime(slot.split("-")[1], time_format).minute)
                       for slot in timeslot_list]

        max_min = max(end_minutes) - min(start_minutes)

        start_lookup = model.NewIntVar(0, max_min, f"{instructor}_{d}_start_min")
        end_lookup   = model.NewIntVar(0, max_min, f"{instructor}_{d}_end_max")

        model.AddElement(earliest, start_minutes, start_lookup)
        model.AddElement(latest, end_minutes, end_lookup)

        duration = model.NewIntVar(0, max_min, f"{instructor}_{d}_span")
        model.Add(duration == end_lookup - start_lookup)

        occupied = model.NewIntVar(0, len(slot_vars) * 180, f"{instructor}_{d}_total_class_time")
        model.Add(occupied == len(slot_vars) * 90)  # each slot is 90 mins

        idle_time = model.NewIntVar(0, max_min, f"{instructor}_{d}_idle")
        model.Add(idle_time == duration - occupied)

        weekly_idle.setdefault(instructor, []).append(idle_time)

        # Soft constraint: daily idle time > 240 min
        idle_violation = model.NewBoolVar(f"{instructor}_{d}_idle_violation")
        model.Add(idle_time > 240).OnlyEnforceIf(idle_violation)
        model.Add(idle_time <= 240).OnlyEnforceIf(idle_violation.Not())

        penalty_vars.append((idle_violation, f"Daily idle >4hr: {instructor} on {d}"))
        penalty_weights.append(50)

# Weekly idle constraint: sum of daily idle time > 660 min (11 hours)
for instructor, idle_vars in weekly_idle.items():
    weekly_total = model.NewIntVar(0, 3000, f"{instructor}_weekly_idle")
    model.Add(weekly_total == sum(idle_vars))

    violation = model.NewBoolVar(f"{instructor}_weekly_idle_violation")
    model.Add(weekly_total > 660).OnlyEnforceIf(violation)
    model.Add(weekly_total <= 660).OnlyEnforceIf(violation.Not())

    penalty_vars.append((violation, f"Weekly idle >11hr: {instructor}"))
    penalty_weights.append(90)

# Step 4: Room-time clash prevention
course_ids = list(valid_schedule['CourseID'])

for i in range(len(course_ids)):
    for j in range(i + 1, len(course_ids)):
        cid1, cid2 = course_ids[i], course_ids[j]

        for idx_a, t1 in enumerate(timeslot_vars[cid1]):
            for idx_b, t2 in enumerate(timeslot_vars[cid2]):
                day_a = valid_schedule.loc[valid_schedule['CourseID'] == cid1, 'Days'].values[0][idx_a]
                day_b = valid_schedule.loc[valid_schedule['CourseID'] == cid2, 'Days'].values[0][idx_b]

                if day_a == day_b:
                    same_room = model.NewBoolVar(f"{cid1}_{cid2}_same_room_{day_a}")
                    same_time = model.NewBoolVar(f"{cid1}_{cid2}_same_time_{day_a}")

                    model.Add(room_vars[cid1] == room_vars[cid2]).OnlyEnforceIf(same_room)
                    model.Add(room_vars[cid1] != room_vars[cid2]).OnlyEnforceIf(same_room.Not())

                    model.Add(t1 == t2).OnlyEnforceIf(same_time)
                    model.Add(t1 != t2).OnlyEnforceIf(same_time.Not())

                    model.AddBoolOr([same_room.Not(), same_time.Not()])

# Step 5: Instructor conflict
instructor_courses = valid_schedule.groupby('Instructor')['CourseID'].apply(list).to_dict()
print("\n👨‍🏫 Instructor Course Mapping:")
for instructor, cids in instructor_courses.items():
    print(f"• {instructor} teaches {len(cids)} courses → {cids}")
    if len(cids) > 5:
        print(f"⚠️ Instructor {instructor} has high teaching load")
    for i in range(len(cids)):
        for j in range(i + 1, len(cids)):
            cid1, cid2 = cids[i], cids[j]
            for t1 in timeslot_vars[cid1]:
                for t2 in timeslot_vars[cid2]:
                    model.Add(t1 != t2)

# Step 6: Room capacity
print("\n🏫 Valid Room Mapping for Capacity:")
for _, row in valid_schedule.iterrows():
    cid = row['CourseID']
    size = int(row['Size'])
    valid_room_indices = [
        room_index[room_name]
        for room_name, capacity in room_size_map.items()
        if pd.notna(capacity) and int(capacity) >= size
    ]
    print(f"• {cid} needs size {size} → {len(valid_room_indices)} valid rooms")
    if not valid_room_indices:
        print(f"❌ No rooms with sufficient capacity for {cid}")
    model.AddAllowedAssignments([room_vars[cid]], [[r] for r in valid_room_indices])

# Step 7: Lab room constraint
print("\n🔬 Lab Room Mapping:")
for _, row in valid_schedule.iterrows():
    cid = row['CourseID']
    if row['IsLab']:
        valid_lab_indices = [
            room_index[r] for r in room_type_map
            if isinstance(room_type_map[r], str) and 'lab' in room_type_map[r].lower()
        ]
        print(f"• {cid} is a lab → {len(valid_lab_indices)} candidate rooms")
        if not valid_lab_indices:
            print(f"❌ No lab rooms found for {cid}")
        model.AddAllowedAssignments([room_vars[cid]], [[r] for r in valid_lab_indices])

        from datetime import datetime

def get_duration_hours(row):
    try:
        fmt = "%H:%M"
        start_dt = datetime.strptime(str(row['Time From']).strip(), fmt)
        end_dt = datetime.strptime(str(row['Time To']).strip(), fmt)
        return (end_dt - start_dt).seconds / 3600
    except:
        return 0

valid_schedule['DurationHrs'] = valid_schedule.apply(get_duration_hours, axis=1)

# For lab courses
lab_durations = valid_schedule[valid_schedule['IsLab']]

print("Lab duration breakdown:")
print(lab_durations['DurationHrs'].value_counts(bins=[0, 1.7, 2.3, 3.2], sort=False))

for _, row in valid_schedule.iterrows():
    cid = row['CourseID']
    preferred_room = row['Room'] if pd.notna(row['Room']) else None
    preferred_time_from = row['Time From'] if pd.notna(row['Time From']) else None
    preferred_time_to = row['Time To'] if pd.notna(row['Time To']) else None
    days = row['Days']

    # print(f"⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️")

    # 🏫 ROOM PREFERENCE PENALTY
    if preferred_room in room_index:
        pref_room_idx = room_index[preferred_room]
        room_match = model.NewBoolVar(f"room_pref_match_{cid}")
        model.Add(room_vars[cid] == pref_room_idx).OnlyEnforceIf(room_match)
        model.Add(room_vars[cid] != pref_room_idx).OnlyEnforceIf(room_match.Not())
        # penalty_vars.append(room_match.Not())  # 1 if not matched
        # penalty_weights.append(50)  # e.g., room preference penalty weight
        penalty_vars.append((room_match.Not(), f"Room preference mismatch for {cid}"))
        penalty_weights.append(50)

    # 🕒 TIME PREFERENCE PENALTY (match any day slot)
    try:
        from_str = pd.to_datetime(preferred_time_from).strftime("%H:%M:%S")
        to_str = pd.to_datetime(preferred_time_to).strftime("%H:%M:%S")
        time_str = f"{from_str}-{to_str}"

        matched_indices = [
            idx for idx, slot in enumerate(timeslot_list)
            if slot.startswith(time_str) and slot.split("-")[-1] in days
        ]

        if not matched_indices:
            print(f"❌ No matching slot found for {cid}: preferred {time_str}, days {days}")
        else:
            print(f"✅ {cid} → Preferred {time_str} matched to slots {[timeslot_list[i] for i in matched_indices]}")


        if matched_indices:
            for i, t_var in enumerate(timeslot_vars[cid]):
                time_match = model.NewBoolVar(f"time_pref_match_{cid}_{i}")
                model.AddAllowedAssignments([t_var], [[idx] for idx in matched_indices]).OnlyEnforceIf(time_match)
                model.AddForbiddenAssignments([t_var], [[idx] for idx in matched_indices]).OnlyEnforceIf(time_match.Not())
                # penalty_vars.append(time_match.Not())  # 1 if not matched
                # penalty_weights.append(30)  # e.g., time preference penalty weight
                # penalty_vars.append((time_match.Not(), f"Time preference mismatch for {cid}"))
                # penalty_weights.append(30)
    except:
        pass

# 🧠 MINIMIZE TOTAL PENALTIES
# model.Minimize(sum(w * v for w, v in zip(penalty_weights, penalty_vars)))
model.Minimize(sum(w * var for (var, _), w in zip(penalty_vars, penalty_weights)))


# Step 8: Solve the model
solver = cp_model.CpSolver()
status = solver.Solve(model)

print(f"\n📊 Solver status: {solver.StatusName(status)}")
print(f"🕒 Wall time: {solver.WallTime():.2f}s")
print(f"🔁 Conflicts: {solver.NumConflicts()}")
print(f"↪️ Branches: {solver.NumBranches()}")

# Only one solution attempted in basic solve, SolutionCount is not available.
print(f"📏 (Note: Only one solution attempted — use a solution callback to enumerate more)")

if status in [cp_model.OPTIMAL, cp_model.FEASIBLE]:
    records = []
    for _, row in valid_schedule.iterrows():
        cid = row['CourseID']
        section = row['Section']
        course = row['Course']
        actual_room = room_list[solver.Value(room_vars[cid])]
        preferred_room = row['Room'] if pd.notna(row['Room']) else None

        for i, d in enumerate(row['Days']):
            ts_index = solver.Value(timeslot_vars[cid][i])
            ts_string = timeslot_list[ts_index]
            time_from, time_to, day = ts_string.split('-')

            pref_time_from = pd.to_datetime(row['Time From']).strftime("%H:%M:%S")
            pref_time_to   = pd.to_datetime(row['Time To']).strftime("%H:%M:%S")

            pref_time_match = (
                pref_time_from == time_from and
                pref_time_to == time_to
            )

            pref_room_match = (
                preferred_room == actual_room
            )


            if not pref_time_match:
                print(f"❌ {cid} did NOT get preferred slot → Time: {row['Time From']}–{row['Time To']} ≠ {time_from}–{time_to}")
            else:
                print(f"✅ {cid} got preferred slot → Time: {row['Time From']}–{row['Time To']} = {time_from}–{time_to}")

            if preferred_room is None:
                print(f"ℹ️ {cid} had no preferred room → Assigned: {actual_room}")
            elif not pref_room_match:
                print(f"❌ {cid} did NOT get preferred room → {preferred_room} ≠ {actual_room}")
            else:
                print(f"✅ {cid} got preferred room → {preferred_room} = {actual_room}")


            # 📝 Final schedule entry
            records.append({
                'Course': course,
                'Section': section,
                'Instructor': row['Instructor'],
                'Day': d,
                'Room': actual_room,
                'Time From': time_from,
                'Time To': time_to
            })

    result_df = pd.DataFrame(records)
    print("🧠 Total courses scheduled:", len(result_df['Course'].unique()))
    print("📚 Total slots used:", len(result_df))
    print("🏫 Room usage breakdown:\n", result_df['Room'].value_counts())
    result_df.to_excel("final_schedule_output.xlsx", index=False)
    print("✅ Output written to final_schedule_output.xlsx")
else:
    print("❌ No feasible solution found.")
    # with open("model_dump.txt", "w") as f:
    #     f.write(str(model))
    # print("📄 Model structure dumped to model_dump.txt")
print("\n📋 Soft Constraint Violations:")
violated_count = 0
for (var, description), weight in zip(penalty_vars, penalty_weights):
    if solver.BooleanValue(var):
        print(f"❌ {description} | Penalty: {weight}")
        violated_count += 1
print(f"🔎 Total Violations: {violated_count} out of {len(penalty_vars)}")
# Out:
# /tmp/ipython-input-259687487.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   valid_schedule['Time From'] = pd.to_datetime(valid_schedule['Time From']).dt.strftime("%H:%M:%S")
# /tmp/ipython-input-259687487.py:19: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   valid_schedule['Time To']   = pd.to_datetime(valid_schedule['Time To']).dt.strftime("%H:%M:%S")
#     Course  Section  Term  Year  Size Time From   Time To Weekday Instructor  \
# 0   ACT101        1     2  2025    30  10:10:00  11:40:00      MW       MRDI
# 1   ACT101        2     2  2025    30  01:30:00  03:00:00      TR        NHN
# 2   ACT101        3     2  2025    30  11:50:00  01:20:00      ST        NHN
# 3   ACT101        4     2  2025    30  08:30:00  10:00:00      SR        THD
# 4   ACT101        5     2  2025    30  11:50:00  01:20:00      ST        THD
# 5   ACT101        6     2  2025    30  10:10:00  11:40:00      MW        THD
# 6   ACT101        7     2  2025    30  08:30:00  10:00:00      MW       MSQI
# 7   ACT101        8     2  2025    30  11:50:00  01:20:00      ST       MSQI
# 8   ACT101        9     2  2025    30  01:30:00  03:00:00      MW       MHRN
# 9   ACT101       10     2  2025    30  01:30:00  03:00:00      SR       MHRN
# 10  ACT101       11     2  2025    30  04:50:00  06:20:00      TR       MHRN
# 11  ACT101       12     2  2025    30  11:50:00  01:20:00      MW       TOMA
# 12  ACT101       13     2  2025    30  03:10:00  04:40:00      MW       TOMA
# 13  ACT201        1     2  2025    30  10:10:00  11:40:00      ST       MRDI
# 14  ACT201        2     2  2025    30  01:30:00  03:00:00      MW        ZMD
# 15  ACT201        3     2  2025    30  01:30:00  03:00:00      MW        NHN
# 16  ACT201        4     2  2025    30  11:50:00  01:20:00      MW        NHN
# 17  ACT201        5     2  2025    30  11:50:00  01:20:00      MW        THD
# 18  ACT201        6     2  2025    30  08:30:00  10:00:00      SR       MSQI
# 19  ACT201        7     2  2025    30  11:50:00  01:20:00      ST       TOMA
# 20  ACT201        8     2  2025    30  03:10:00  04:40:00      TR       TOMA
# 21  ACT411        1     2  2025    30  01:30:00  03:00:00      ST       DACY
# 22  ACT411        2     2  2025    30  11:50:00  01:20:00      MW       MSQI
# 23  ACT421        1     2  2025    30  01:30:00  03:00:00      ST        ZMD
# 24  ACT421        2     2  2025    30  03:10:00  04:40:00      ST        ZMD
# 25  ACT425        1     2  2025    30  10:10:00  11:40:00      MW       MHRN
# 26  ACT441        1     2  2025    30  10:10:00  11:40:00      MW        NCS
# 27  ACT441        2     2  2025    30  11:50:00  01:20:00      MW        NCS
# 28  ACT442        1     2  2025    30  11:50:00  01:20:00      ST       DACY
# 29  ACT447        1     2  2025    30  01:30:00  03:00:00      MW       DACY
# 30  ACT478        1     2  2025    30  10:10:00  11:40:00      ST        NCS
# 31  BUS231        1     2  2025    30  01:30:00  03:00:00      TR         KH
# 32  BUS231        2     2  2025    30  11:50:00  01:20:00      MW         KB
# 33  BUS231        3     2  2025    30  03:10:00  04:40:00      MW         KB
# 34  BUS231        4     2  2025    30  08:30:00  10:00:00      MW        FZK
# 35  BUS231        5     2  2025    30  08:30:00  10:00:00      MW   ASIFSAMI
# 36  BUS231        6     2  2025    30  11:50:00  01:20:00      MW   ASIFSAMI
# 37  BUS231        7     2  2025    30  08:30:00  10:00:00      ST       SDRN
# 38  BUS231        8     2  2025    30  11:50:00  01:20:00      TR       SDRN
# 39  BUS231        9     2  2025    30  01:30:00  03:00:00      MW       SDRN
# 40  BUS361        1     2  2025    30  01:30:00  03:00:00      MW       MHSL
# 41  BUS361        2     2  2025    30  10:10:00  11:40:00      ST       MHSL
# 42  BUS361        3     2  2025    30  11:50:00  01:20:00      MW         MN
# 43  BUS361        4     2  2025    30  01:30:00  03:00:00      SR         MN
# 44  BUS361        5     2  2025    30  08:30:00  10:00:00      ST     TANBIR
# 45  BUS361        6     2  2025    30  08:30:00  10:00:00      MW     TANBIR
# 46  BUS361        7     2  2025    30  01:30:00  03:00:00      TR        NAA
# 47   CE100        2     2  2025    30  01:30:00  03:30:00       T       DMKT
# 48   CE100        3     2  2025    30  10:10:00  12:10:00       M       KASB
# 49   CE101        1     2  2025    40  03:10:00  04:40:00      MW       DMNH
#
#                  Room Parellal   CourseID  IsLab    Days  NumDays  \
# 0                 110      NaN   ACT101_1  False  [M, W]        2
# 1                 NaN      NaN   ACT101_2  False  [T, R]        2
# 2                 NaN      NaN   ACT101_3  False  [S, T]        2
# 3                 NaN      NaN   ACT101_4  False  [S, R]        2
# 4                 NaN      NaN   ACT101_5  False  [S, T]        2
# 5                 110      NaN   ACT101_6  False  [M, W]        2
# 6                 NaN      NaN   ACT101_7  False  [M, W]        2
# 7                 NaN      NaN   ACT101_8  False  [S, T]        2
# 8                 NaN      NaN   ACT101_9  False  [M, W]        2
# 9                 NaN      NaN  ACT101_10  False  [S, R]        2
# 10                NaN      NaN  ACT101_11  False  [T, R]        2
# 11                NaN      NaN  ACT101_12  False  [M, W]        2
# 12                NaN      NaN  ACT101_13  False  [M, W]        2
# 13                NaN      NaN   ACT201_1  False  [S, T]        2
# 14                NaN      NaN   ACT201_2  False  [M, W]        2
# 15                NaN      NaN   ACT201_3  False  [M, W]        2
# 16                NaN      NaN   ACT201_4  False  [M, W]        2
# 17                NaN      NaN   ACT201_5  False  [M, W]        2
# 18                NaN      NaN   ACT201_6  False  [S, R]        2
# 19                NaN      NaN   ACT201_7  False  [S, T]        2
# 20                NaN      NaN   ACT201_8  False  [T, R]        2
# 21                336      NaN   ACT411_1  False  [S, T]        2
# 22                NaN      NaN   ACT411_2  False  [M, W]        2
# 23                NaN      NaN   ACT421_1  False  [S, T]        2
# 24                NaN      NaN   ACT421_2  False  [S, T]        2
# 25                NaN      NaN   ACT425_1  False  [M, W]        2
# 26                429      NaN   ACT441_1  False  [M, W]        2
# 27                429      NaN   ACT441_2  False  [M, W]        2
# 28                336      NaN   ACT442_1  False  [S, T]        2
# 29                336      NaN   ACT447_1  False  [M, W]        2
# 30                429      NaN   ACT478_1  False  [S, T]        2
# 31                NaN      NaN   BUS231_1  False  [T, R]        2
# 32                NaN      NaN   BUS231_2  False  [M, W]        2
# 33                NaN      NaN   BUS231_3  False  [M, W]        2
# 34                NaN      NaN   BUS231_4  False  [M, W]        2
# 35                NaN      NaN   BUS231_5  False  [M, W]        2
# 36                NaN      NaN   BUS231_6  False  [M, W]        2
# 37                NaN      NaN   BUS231_7  False  [S, T]        2
# 38                NaN      NaN   BUS231_8  False  [T, R]        2
# 39                NaN      NaN   BUS231_9  False  [M, W]        2
# 40                NaN      NaN   BUS361_1  False  [M, W]        2
# 41                NaN      NaN   BUS361_2  False  [S, T]        2
# 42                NaN      NaN   BUS361_3  False  [M, W]        2
# 43                NaN      NaN   BUS361_4  False  [S, R]        2
# 44                NaN      NaN   BUS361_5  False  [S, T]        2
# 45                NaN      NaN   BUS361_6  False  [M, W]        2
# 46                NaN      NaN   BUS361_7  False  [T, R]        2
# 47  352 (Drawing Lab)   CE7100    CE100_2  False     [T]        1
# 48  352 (Drawing Lab)   CE7100    CE100_3  False     [M]        1
# 49        main campus   CE7101    CE101_1  False  [M, W]        2
#
#                          faculty name          Designation         department  \
# 0              DR. MD. RASHIDUL ISLAM            Professor                BBA
# 1                   MR. NAZMUL HASSAN            Professor                BBA
# 2                   MR. NAZMUL HASSAN            Professor                BBA
# 3                     MS. TANIA HAMID      Senior Lecturer                BBA
# 4                     MS. TANIA HAMID      Senior Lecturer                BBA
# 5                     MS. TANIA HAMID      Senior Lecturer                BBA
# 6                  MD. SHAFIQUL ISLAM      Senior Lecturer                MPS
# 7                  MD. SHAFIQUL ISLAM      Senior Lecturer                MPS
# 8                 Mr. Moshiour Rahman             Lecturer                BBA
# 9                 Mr. Moshiour Rahman             Lecturer                BBA
# 10                Mr. Moshiour Rahman             Lecturer                BBA
# 11              Ms. Nusrat Jahan Toma             Lecturer                BBA
# 12              Ms. Nusrat Jahan Toma             Lecturer                BBA
# 13             DR. MD. RASHIDUL ISLAM            Professor                BBA
# 14         Dr. Mohammad Zakaria Masud  Associate Professor                BBA
# 15                  MR. NAZMUL HASSAN            Professor                BBA
# 16                  MR. NAZMUL HASSAN            Professor                BBA
# 17                    MS. TANIA HAMID      Senior Lecturer                BBA
# 18                 MD. SHAFIQUL ISLAM      Senior Lecturer                MPS
# 19              Ms. Nusrat Jahan Toma             Lecturer                BBA
# 20              Ms. Nusrat Jahan Toma             Lecturer                BBA
# 21                 DR. ANUP CHOWDHURY            Professor                BBA
# 22                 MD. SHAFIQUL ISLAM      Senior Lecturer                MPS
# 23         Dr. Mohammad Zakaria Masud  Associate Professor                BBA
# 24         Dr. Mohammad Zakaria Masud  Associate Professor                BBA
# 25                Mr. Moshiour Rahman             Lecturer                BBA
# 26            DR. NIKHIL CHANDRA SHIL            Professor                BBA
# 27            DR. NIKHIL CHANDRA SHIL            Professor                BBA
# 28                 DR. ANUP CHOWDHURY            Professor                BBA
# 29                 DR. ANUP CHOWDHURY            Professor                BBA
# 30            DR. NIKHIL CHANDRA SHIL            Professor                BBA
# 31                  MR. KAMRUL HASSAN  Assistant Professor                BBA
# 32                MS. KOHINOOR BISWAS  Assistant Professor                BBA
# 33                MS. KOHINOOR BISWAS  Assistant Professor                BBA
# 34                                NaN                  NaN                NaN
# 35                Mr. Ahmad Asif Sami             Lecturer                BBA
# 36                Mr. Ahmad Asif Sami             Lecturer                BBA
# 37                 Mr. Sheedad Rahman             Lecturer                BBA
# 38                 Mr. Sheedad Rahman             Lecturer                BBA
# 39                 Mr. Sheedad Rahman             Lecturer                BBA
# 40                 MOHAMMED SHAHJALAL      Senior Lecturer                BBA
# 41                 MOHAMMED SHAHJALAL      Senior Lecturer                BBA
# 42                    Mashraba Naziat             Lecturer                BBA
# 43                    Mashraba Naziat             Lecturer                BBA
# 44        Mr. Khandker Saad At Tanbir             Lecturer                BBA
# 45        Mr. Khandker Saad At Tanbir             Lecturer                BBA
# 46               Ms. Nur-A Ariya Alam             Lecturer                BBA
# 47  DR. MOHAMMAD KAMRUZZAMAN TALUKDER  Assistant Professor  Civil Engineering
# 48     Dr. Khondoker Al Sabbir Billah  Assistant Professor  Civil Engineering
# 49               DR. MD. NAIMUL HAQUE  Associate Professor  Civil Engineering
#
#          building building preference
# 0   Main Building       Main Building
# 1   Main Building                 NaN
# 2   Main Building                 NaN
# 3   Main Building                 NaN
# 4   Main Building                 NaN
# 5   Main Building                 NaN
# 6             FUB                 NaN
# 7             FUB                 NaN
# 8             AB1                 AB1
# 9             AB1                 AB1
# 10            AB1                 AB1
# 11            AB1                 AB1
# 12            AB1                 AB1
# 13  Main Building       Main Building
# 14  Main Building       Main Building
# 15  Main Building                 NaN
# 16  Main Building                 NaN
# 17  Main Building                 NaN
# 18            FUB                 NaN
# 19            AB1                 AB1
# 20            AB1                 AB1
# 21  Main Building       Main Building
# 22            FUB                 NaN
# 23  Main Building       Main Building
# 24  Main Building       Main Building
# 25            AB1                 AB1
# 26  Main Building       Main Building
# 27  Main Building       Main Building
# 28  Main Building       Main Building
# 29  Main Building       Main Building
# 30  Main Building       Main Building
# 31  Main Building                 NaN
# 32  Main Building                 NaN
# 33  Main Building                 NaN
# 34            NaN                 NaN
# 35  Main Building                 NaN
# 36  Main Building                 NaN
# 37            AB1                 AB1
# 38            AB1                 AB1
# 39            AB1                 AB1
# 40  Main Building                 NaN
# 41  Main Building                 NaN
# 42  Main Building                 NaN
# 43  Main Building                 NaN
# 44  Main Building                 NaN
# 45  Main Building                 NaN
# 46  Main Building                 NaN
# 47  Main Building                 NaN
# 48  Main Building                 NaN
# 49  Main Building       Main Building
# Weekday  SlotType
# M        Lab-2hr     4
#          Lab-3hr     4
#          Theory      7
# R        Lab-2hr     4
#          Lab-3hr     4
#          Theory      7
# S        Lab-2hr     4
#          Lab-3hr     4
#          Theory      7
# T        Lab-2hr     4
#          Lab-3hr     4
#          Theory      7
# W        Lab-2hr     4
#          Lab-3hr     4
#          Theory      7
# dtype: int64
#
# 🧾 Course Summary:
# • ACT101_1: Days=['M', 'W'], IsLab=False, Size=30, Instructor=MRDI
# • ACT101_2: Days=['T', 'R'], IsLab=False, Size=30, Instructor=NHN
# • ACT101_3: Days=['S', 'T'], IsLab=False, Size=30, Instructor=NHN
# • ACT101_4: Days=['S', 'R'], IsLab=False, Size=30, Instructor=THD
# • ACT101_5: Days=['S', 'T'], IsLab=False, Size=30, Instructor=THD
# • ACT101_6: Days=['M', 'W'], IsLab=False, Size=30, Instructor=THD
# • ACT101_7: Days=['M', 'W'], IsLab=False, Size=30, Instructor=MSQI
# • ACT101_8: Days=['S', 'T'], IsLab=False, Size=30, Instructor=MSQI
# • ACT101_9: Days=['M', 'W'], IsLab=False, Size=30, Instructor=MHRN
# • ACT101_10: Days=['S', 'R'], IsLab=False, Size=30, Instructor=MHRN
# • ACT101_11: Days=['T', 'R'], IsLab=False, Size=30, Instructor=MHRN
# • ACT101_12: Days=['M', 'W'], IsLab=False, Size=30, Instructor=TOMA
# • ACT101_13: Days=['M', 'W'], IsLab=False, Size=30, Instructor=TOMA
# • ACT201_1: Days=['S', 'T'], IsLab=False, Size=30, Instructor=MRDI
# • ACT201_2: Days=['M', 'W'], IsLab=False, Size=30, Instructor=ZMD
# • ACT201_3: Days=['M', 'W'], IsLab=False, Size=30, Instructor=NHN
# • ACT201_4: Days=['M', 'W'], IsLab=False, Size=30, Instructor=NHN
# • ACT201_5: Days=['M', 'W'], IsLab=False, Size=30, Instructor=THD
# • ACT201_6: Days=['S', 'R'], IsLab=False, Size=30, Instructor=MSQI
# • ACT201_7: Days=['S', 'T'], IsLab=False, Size=30, Instructor=TOMA
# • ACT201_8: Days=['T', 'R'], IsLab=False, Size=30, Instructor=TOMA
# • ACT411_1: Days=['S', 'T'], IsLab=False, Size=30, Instructor=DACY
# • ACT411_2: Days=['M', 'W'], IsLab=False, Size=30, Instructor=MSQI
# • ACT421_1: Days=['S', 'T'], IsLab=False, Size=30, Instructor=ZMD
# • ACT421_2: Days=['S', 'T'], IsLab=False, Size=30, Instructor=ZMD
# • ACT425_1: Days=['M', 'W'], IsLab=False, Size=30, Instructor=MHRN
# • ACT441_1: Days=['M', 'W'], IsLab=False, Size=30, Instructor=NCS
# • ACT441_2: Days=['M', 'W'], IsLab=False, Size=30, Instructor=NCS
# • ACT442_1: Days=['S', 'T'], IsLab=False, Size=30, Instructor=DACY
# • ACT447_1: Days=['M', 'W'], IsLab=False, Size=30, Instructor=DACY
# • ACT478_1: Days=['S', 'T'], IsLab=False, Size=30, Instructor=NCS
# • BUS231_1: Days=['T', 'R'], IsLab=False, Size=30, Instructor=KH
# • BUS231_2: Days=['M', 'W'], IsLab=False, Size=30, Instructor=KB
# • BUS231_3: Days=['M', 'W'], IsLab=False, Size=30, Instructor=KB
# • BUS231_4: Days=['M', 'W'], IsLab=False, Size=30, Instructor=FZK
# • BUS231_5: Days=['M', 'W'], IsLab=False, Size=30, Instructor=ASIFSAMI
# • BUS231_6: Days=['M', 'W'], IsLab=False, Size=30, Instructor=ASIFSAMI
# • BUS231_7: Days=['S', 'T'], IsLab=False, Size=30, Instructor=SDRN
# • BUS231_8: Days=['T', 'R'], IsLab=False, Size=30, Instructor=SDRN
# • BUS231_9: Days=['M', 'W'], IsLab=False, Size=30, Instructor=SDRN
# • BUS361_1: Days=['M', 'W'], IsLab=False, Size=30, Instructor=MHSL
# • BUS361_2: Days=['S', 'T'], IsLab=False, Size=30, Instructor=MHSL
# • BUS361_3: Days=['M', 'W'], IsLab=False, Size=30, Instructor=MN
# • BUS361_4: Days=['S', 'R'], IsLab=False, Size=30, Instructor=MN
# • BUS361_5: Days=['S', 'T'], IsLab=False, Size=30, Instructor=TANBIR
# • BUS361_6: Days=['M', 'W'], IsLab=False, Size=30, Instructor=TANBIR
# • BUS361_7: Days=['T', 'R'], IsLab=False, Size=30, Instructor=NAA
# • CE100_2: Days=['T'], IsLab=False, Size=30, Instructor=DMKT
# • CE100_3: Days=['M'], IsLab=False, Size=30, Instructor=KASB
# • CE101_1: Days=['M', 'W'], IsLab=False, Size=40, Instructor=DMNH
# • CE101_2: Days=['M', 'W'], IsLab=False, Size=40, Instructor=TBA1
# • CE102_1: Days=['T'], IsLab=False, Size=30, Instructor=KASB
# • CE102_2: Days=['W'], IsLab=False, Size=30, Instructor=KASB
# • CE102_3: Days=['M'], IsLab=False, Size=30, Instructor=SDR
# • CE103_1: Days=['M', 'W'], IsLab=False, Size=30, Instructor=MRMK
# • CE103_2: Days=['S', 'T'], IsLab=False, Size=30, Instructor=SDR
# • CE103Lab_1: Days=['S'], IsLab=True, Size=30, Instructor=MRMK
# • CE103Lab_2: Days=['S'], IsLab=True, Size=30, Instructor=SDR
# • CE200_1: Days=['M'], IsLab=False, Size=40, Instructor=SADIK
# • CE201_1: Days=['T', 'R'], IsLab=False, Size=30, Instructor=DMTS
# • CE201_2: Days=['S', 'T'], IsLab=False, Size=30, Instructor=MRMK
# • CE203_1: Days=['M', 'W'], IsLab=False, Size=40, Instructor=MRMK
# • CE203_2: Days=['S', 'T'], IsLab=False, Size=40, Instructor=SADIK
# • CE208_1: Days=['R'], IsLab=False, Size=40, Instructor=SADIK
# • CE211_1: Days=['S', 'T'], IsLab=False, Size=30, Instructor=DMNH
# • CE211_2: Days=['S', 'R'], IsLab=False, Size=30, Instructor=TBA1
# • CE211Lab_1: Days=['M'], IsLab=True, Size=30, Instructor=DMNH
# • CE213_1: Days=['M', 'W'], IsLab=False, Size=40, Instructor=TBA1
# • CE213_2: Days=['S', 'T'], IsLab=False, Size=40, Instructor=TBA2
# • CE261_1: Days=['S', 'R'], IsLab=False, Size=30, Instructor=KASB
# • CE261_2: Days=['T', 'R'], IsLab=False, Size=30, Instructor=TBA2
#
# 🏃 Back-to-back same building constraint:
#
# 🕒 Idle Time Constraints:
#
# 👨‍🏫 Instructor Course Mapping:
# • ASIFSAMI teaches 2 courses → ['BUS231_5', 'BUS231_6']
# • DACY teaches 3 courses → ['ACT411_1', 'ACT442_1', 'ACT447_1']
# • DMKT teaches 1 courses → ['CE100_2']
# • DMNH teaches 3 courses → ['CE101_1', 'CE211_1', 'CE211Lab_1']
# • DMTS teaches 1 courses → ['CE201_1']
# • FZK teaches 1 courses → ['BUS231_4']
# • KASB teaches 4 courses → ['CE100_3', 'CE102_1', 'CE102_2', 'CE261_1']
# • KB teaches 2 courses → ['BUS231_2', 'BUS231_3']
# • KH teaches 1 courses → ['BUS231_1']
# • MHRN teaches 4 courses → ['ACT101_9', 'ACT101_10', 'ACT101_11', 'ACT425_1']
# • MHSL teaches 2 courses → ['BUS361_1', 'BUS361_2']
# • MN teaches 2 courses → ['BUS361_3', 'BUS361_4']
# • MRDI teaches 2 courses → ['ACT101_1', 'ACT201_1']
# • MRMK teaches 4 courses → ['CE103_1', 'CE103Lab_1', 'CE201_2', 'CE203_1']
# • MSQI teaches 4 courses → ['ACT101_7', 'ACT101_8', 'ACT201_6', 'ACT411_2']
# • NAA teaches 1 courses → ['BUS361_7']
# • NCS teaches 3 courses → ['ACT441_1', 'ACT441_2', 'ACT478_1']
# • NHN teaches 4 courses → ['ACT101_2', 'ACT101_3', 'ACT201_3', 'ACT201_4']
# • SADIK teaches 3 courses → ['CE200_1', 'CE203_2', 'CE208_1']
# • SDR teaches 3 courses → ['CE102_3', 'CE103_2', 'CE103Lab_2']
# • SDRN teaches 3 courses → ['BUS231_7', 'BUS231_8', 'BUS231_9']
# • TANBIR teaches 2 courses → ['BUS361_5', 'BUS361_6']
# • TBA1 teaches 3 courses → ['CE101_2', 'CE211_2', 'CE213_1']
# • TBA2 teaches 2 courses → ['CE213_2', 'CE261_2']
# • THD teaches 4 courses → ['ACT101_4', 'ACT101_5', 'ACT101_6', 'ACT201_5']
# • TOMA teaches 4 courses → ['ACT101_12', 'ACT101_13', 'ACT201_7', 'ACT201_8']
# • ZMD teaches 3 courses → ['ACT201_2', 'ACT421_1', 'ACT421_2']
#
# 🏫 Valid Room Mapping for Capacity:
# • ACT101_1 needs size 30 → 123 valid rooms
# • ACT101_2 needs size 30 → 123 valid rooms
# • ACT101_3 needs size 30 → 123 valid rooms
# • ACT101_4 needs size 30 → 123 valid rooms
# • ACT101_5 needs size 30 → 123 valid rooms
# • ACT101_6 needs size 30 → 123 valid rooms
# • ACT101_7 needs size 30 → 123 valid rooms
# • ACT101_8 needs size 30 → 123 valid rooms
# • ACT101_9 needs size 30 → 123 valid rooms
# • ACT101_10 needs size 30 → 123 valid rooms
# • ACT101_11 needs size 30 → 123 valid rooms
# • ACT101_12 needs size 30 → 123 valid rooms
# • ACT101_13 needs size 30 → 123 valid rooms
# • ACT201_1 needs size 30 → 123 valid rooms
# • ACT201_2 needs size 30 → 123 valid rooms
# • ACT201_3 needs size 30 → 123 valid rooms
# • ACT201_4 needs size 30 → 123 valid rooms
# • ACT201_5 needs size 30 → 123 valid rooms
# • ACT201_6 needs size 30 → 123 valid rooms
# • ACT201_7 needs size 30 → 123 valid rooms
# • ACT201_8 needs size 30 → 123 valid rooms
# • ACT411_1 needs size 30 → 123 valid rooms
# • ACT411_2 needs size 30 → 123 valid rooms
# • ACT421_1 needs size 30 → 123 valid rooms
# • ACT421_2 needs size 30 → 123 valid rooms
# • ACT425_1 needs size 30 → 123 valid rooms
# • ACT441_1 needs size 30 → 123 valid rooms
# • ACT441_2 needs size 30 → 123 valid rooms
# • ACT442_1 needs size 30 → 123 valid rooms
# • ACT447_1 needs size 30 → 123 valid rooms
# • ACT478_1 needs size 30 → 123 valid rooms
# • BUS231_1 needs size 30 → 123 valid rooms
# • BUS231_2 needs size 30 → 123 valid rooms
# • BUS231_3 needs size 30 → 123 valid rooms
# • BUS231_4 needs size 30 → 123 valid rooms
# • BUS231_5 needs size 30 → 123 valid rooms
# • BUS231_6 needs size 30 → 123 valid rooms
# • BUS231_7 needs size 30 → 123 valid rooms
# • BUS231_8 needs size 30 → 123 valid rooms
# • BUS231_9 needs size 30 → 123 valid rooms
# • BUS361_1 needs size 30 → 123 valid rooms
# • BUS361_2 needs size 30 → 123 valid rooms
# • BUS361_3 needs size 30 → 123 valid rooms
# • BUS361_4 needs size 30 → 123 valid rooms
# • BUS361_5 needs size 30 → 123 valid rooms
# • BUS361_6 needs size 30 → 123 valid rooms
# • BUS361_7 needs size 30 → 123 valid rooms
# • CE100_2 needs size 30 → 123 valid rooms
# • CE100_3 needs size 30 → 123 valid rooms
# • CE101_1 needs size 40 → 83 valid rooms
# • CE101_2 needs size 40 → 83 valid rooms
# • CE102_1 needs size 30 → 123 valid rooms
# • CE102_2 needs size 30 → 123 valid rooms
# • CE102_3 needs size 30 → 123 valid rooms
# • CE103_1 needs size 30 → 123 valid rooms
# • CE103_2 needs size 30 → 123 valid rooms
# • CE103Lab_1 needs size 30 → 123 valid rooms
# • CE103Lab_2 needs size 30 → 123 valid rooms
# • CE200_1 needs size 40 → 83 valid rooms
# • CE201_1 needs size 30 → 123 valid rooms
# • CE201_2 needs size 30 → 123 valid rooms
# • CE203_1 needs size 40 → 83 valid rooms
# • CE203_2 needs size 40 → 83 valid rooms
# • CE208_1 needs size 40 → 83 valid rooms
# • CE211_1 needs size 30 → 123 valid rooms
# • CE211_2 needs size 30 → 123 valid rooms
# • CE211Lab_1 needs size 30 → 123 valid rooms
# • CE213_1 needs size 40 → 83 valid rooms
# • CE213_2 needs size 40 → 83 valid rooms
# • CE261_1 needs size 30 → 123 valid rooms
# • CE261_2 needs size 30 → 123 valid rooms
#
# 🔬 Lab Room Mapping:
# • CE103Lab_1 is a lab → 37 candidate rooms
# • CE103Lab_2 is a lab → 37 candidate rooms
# • CE211Lab_1 is a lab → 37 candidate rooms
# Lab duration breakdown:
# (-0.001, 1.7]    3
# (1.7, 2.3]       0
# (2.3, 3.2]       0
# Name: count, dtype: int64
# ✅ ACT101_1 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-M', '10:10:00-11:40:00-W']
# ✅ ACT101_2 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-T', '01:30:00-03:00:00-R']
# ✅ ACT101_3 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-S', '11:50:00-01:20:00-T']
# ✅ ACT101_4 → Preferred 08:30:00-10:00:00 matched to slots ['08:30:00-10:00:00-S', '08:30:00-10:00:00-R']
# ✅ ACT101_5 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-S', '11:50:00-01:20:00-T']
# ✅ ACT101_6 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-M', '10:10:00-11:40:00-W']
# ✅ ACT101_7 → Preferred 08:30:00-10:00:00 matched to slots ['08:30:00-10:00:00-M', '08:30:00-10:00:00-W']
# ✅ ACT101_8 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-S', '11:50:00-01:20:00-T']
# ✅ ACT101_9 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-M', '01:30:00-03:00:00-W']
# ✅ ACT101_10 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-S', '01:30:00-03:00:00-R']
# ✅ ACT101_11 → Preferred 04:50:00-06:20:00 matched to slots ['04:50:00-06:20:00-T', '04:50:00-06:20:00-R']
# ✅ ACT101_12 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ ACT101_13 → Preferred 03:10:00-04:40:00 matched to slots ['03:10:00-04:40:00-M', '03:10:00-04:40:00-W']
# ✅ ACT201_1 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-S', '10:10:00-11:40:00-T']
# ✅ ACT201_2 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-M', '01:30:00-03:00:00-W']
# ✅ ACT201_3 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-M', '01:30:00-03:00:00-W']
# ✅ ACT201_4 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ ACT201_5 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ ACT201_6 → Preferred 08:30:00-10:00:00 matched to slots ['08:30:00-10:00:00-S', '08:30:00-10:00:00-R']
# ✅ ACT201_7 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-S', '11:50:00-01:20:00-T']
# ✅ ACT201_8 → Preferred 03:10:00-04:40:00 matched to slots ['03:10:00-04:40:00-T', '03:10:00-04:40:00-R']
# ✅ ACT411_1 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-S', '01:30:00-03:00:00-T']
# ✅ ACT411_2 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ ACT421_1 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-S', '01:30:00-03:00:00-T']
# ✅ ACT421_2 → Preferred 03:10:00-04:40:00 matched to slots ['03:10:00-04:40:00-S', '03:10:00-04:40:00-T']
# ✅ ACT425_1 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-M', '10:10:00-11:40:00-W']
# ✅ ACT441_1 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-M', '10:10:00-11:40:00-W']
# ✅ ACT441_2 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ ACT442_1 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-S', '11:50:00-01:20:00-T']
# ✅ ACT447_1 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-M', '01:30:00-03:00:00-W']
# ✅ ACT478_1 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-S', '10:10:00-11:40:00-T']
# ✅ BUS231_1 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-T', '01:30:00-03:00:00-R']
# ✅ BUS231_2 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ BUS231_3 → Preferred 03:10:00-04:40:00 matched to slots ['03:10:00-04:40:00-M', '03:10:00-04:40:00-W']
# ✅ BUS231_4 → Preferred 08:30:00-10:00:00 matched to slots ['08:30:00-10:00:00-M', '08:30:00-10:00:00-W']
# ✅ BUS231_5 → Preferred 08:30:00-10:00:00 matched to slots ['08:30:00-10:00:00-M', '08:30:00-10:00:00-W']
# ✅ BUS231_6 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ BUS231_7 → Preferred 08:30:00-10:00:00 matched to slots ['08:30:00-10:00:00-S', '08:30:00-10:00:00-T']
# ✅ BUS231_8 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-T', '11:50:00-01:20:00-R']
# ✅ BUS231_9 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-M', '01:30:00-03:00:00-W']
# ✅ BUS361_1 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-M', '01:30:00-03:00:00-W']
# ✅ BUS361_2 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-S', '10:10:00-11:40:00-T']
# ✅ BUS361_3 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ BUS361_4 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-S', '01:30:00-03:00:00-R']
# ✅ BUS361_5 → Preferred 08:30:00-10:00:00 matched to slots ['08:30:00-10:00:00-S', '08:30:00-10:00:00-T']
# ✅ BUS361_6 → Preferred 08:30:00-10:00:00 matched to slots ['08:30:00-10:00:00-M', '08:30:00-10:00:00-W']
# ✅ BUS361_7 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-T', '01:30:00-03:00:00-R']
# ✅ CE100_2 → Preferred 01:30:00-03:30:00 matched to slots ['01:30:00-03:30:00-T']
# ✅ CE100_3 → Preferred 10:10:00-12:10:00 matched to slots ['10:10:00-12:10:00-M']
# ✅ CE101_1 → Preferred 03:10:00-04:40:00 matched to slots ['03:10:00-04:40:00-M', '03:10:00-04:40:00-W']
# ✅ CE101_2 → Preferred 03:10:00-04:40:00 matched to slots ['03:10:00-04:40:00-M', '03:10:00-04:40:00-W']
# ✅ CE102_1 → Preferred 01:30:00-03:30:00 matched to slots ['01:30:00-03:30:00-T']
# ✅ CE102_2 → Preferred 01:30:00-03:30:00 matched to slots ['01:30:00-03:30:00-W']
# ✅ CE102_3 → Preferred 01:30:00-03:30:00 matched to slots ['01:30:00-03:30:00-M']
# ✅ CE103_1 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-M', '11:50:00-01:20:00-W']
# ✅ CE103_2 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-S', '10:10:00-11:40:00-T']
# ✅ CE103Lab_1 → Preferred 03:10:00-04:40:00 matched to slots ['03:10:00-04:40:00-S']
# ✅ CE103Lab_2 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-S']
# ✅ CE200_1 → Preferred 08:00:00-11:00:00 matched to slots ['08:00:00-11:00:00-M']
# ✅ CE201_1 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-T', '11:50:00-01:20:00-R']
# ✅ CE201_2 → Preferred 11:50:00-01:20:00 matched to slots ['11:50:00-01:20:00-S', '11:50:00-01:20:00-T']
# ✅ CE203_1 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-M', '01:30:00-03:00:00-W']
# ✅ CE203_2 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-S', '01:30:00-03:00:00-T']
# ✅ CE208_1 → Preferred 10:10:00-01:10:00 matched to slots ['10:10:00-01:10:00-R']
# ✅ CE211_1 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-S', '10:10:00-11:40:00-T']
# ✅ CE211_2 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-S', '10:10:00-11:40:00-R']
# ✅ CE211Lab_1 → Preferred 10:10:00-01:10:00 matched to slots ['10:10:00-01:10:00-M']
# ✅ CE213_1 → Preferred 10:10:00-11:40:00 matched to slots ['10:10:00-11:40:00-M', '10:10:00-11:40:00-W']
# ✅ CE213_2 → Preferred 04:50:00-06:20:00 matched to slots ['04:50:00-06:20:00-S', '04:50:00-06:20:00-T']
# ✅ CE261_1 → Preferred 01:30:00-03:00:00 matched to slots ['01:30:00-03:00:00-S', '01:30:00-03:00:00-R']
# ✅ CE261_2 → Preferred 03:10:00-04:40:00 matched to slots ['03:10:00-04:40:00-T', '03:10:00-04:40:00-R']
#
# 📊 Solver status: OPTIMAL
# 🕒 Wall time: 10.73s
# 🔁 Conflicts: 337
# ↪️ Branches: 135530
# 📏 (Note: Only one solution attempted — use a solution callback to enumerate more)
# ✅ ACT101_1 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ✅ ACT101_1 got preferred room → 110 = 110
# ✅ ACT101_1 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ✅ ACT101_1 got preferred room → 110 = 110
# ✅ ACT101_2 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT101_2 had no preferred room → Assigned: 107
# ✅ ACT101_2 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT101_2 had no preferred room → Assigned: 107
# ✅ ACT101_3 got preferred slot → Time: 11:50:00–01:20:00 = 11:50:00–01:20:00
# ℹ️ ACT101_3 had no preferred room → Assigned: 107
# ❌ ACT101_3 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 03:10:00–04:40:00
# ℹ️ ACT101_3 had no preferred room → Assigned: 107
# ❌ ACT101_4 did NOT get preferred slot → Time: 08:30:00–10:00:00 ≠ 03:10:00–04:40:00
# ℹ️ ACT101_4 had no preferred room → Assigned: AB1-301
# ✅ ACT101_4 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ ACT101_4 had no preferred room → Assigned: AB1-301
# ❌ ACT101_5 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 06:30:00–08:00:00
# ℹ️ ACT101_5 had no preferred room → Assigned: AB1-202
# ✅ ACT101_5 got preferred slot → Time: 11:50:00–01:20:00 = 11:50:00–01:20:00
# ℹ️ ACT101_5 had no preferred room → Assigned: AB1-202
# ❌ ACT101_6 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 03:10:00–04:40:00
# ✅ ACT101_6 got preferred room → 110 = 110
# ❌ ACT101_6 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 03:10:00–04:40:00
# ✅ ACT101_6 got preferred room → 110 = 110
# ❌ ACT101_7 did NOT get preferred slot → Time: 08:30:00–10:00:00 ≠ 04:50:00–06:20:00
# ℹ️ ACT101_7 had no preferred room → Assigned: 430
# ❌ ACT101_7 did NOT get preferred slot → Time: 08:30:00–10:00:00 ≠ 04:50:00–06:20:00
# ℹ️ ACT101_7 had no preferred room → Assigned: 430
# ❌ ACT101_8 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ℹ️ ACT101_8 had no preferred room → Assigned: 431 (Multi Media and Image Processing Lab)
# ✅ ACT101_8 got preferred slot → Time: 11:50:00–01:20:00 = 11:50:00–01:20:00
# ℹ️ ACT101_8 had no preferred room → Assigned: 431 (Multi Media and Image Processing Lab)
# ✅ ACT101_9 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT101_9 had no preferred room → Assigned: 222
# ✅ ACT101_9 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT101_9 had no preferred room → Assigned: 222
# ✅ ACT101_10 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT101_10 had no preferred room → Assigned: AB1-301
# ✅ ACT101_10 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT101_10 had no preferred room → Assigned: AB1-301
# ✅ ACT101_11 got preferred slot → Time: 04:50:00–06:20:00 = 04:50:00–06:20:00
# ℹ️ ACT101_11 had no preferred room → Assigned: 436 (Human-Computer Interaction Lab)
# ✅ ACT101_11 got preferred slot → Time: 04:50:00–06:20:00 = 04:50:00–06:20:00
# ℹ️ ACT101_11 had no preferred room → Assigned: 436 (Human-Computer Interaction Lab)
# ❌ ACT101_12 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 06:30:00–08:00:00
# ℹ️ ACT101_12 had no preferred room → Assigned: 110
# ❌ ACT101_12 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 06:30:00–08:00:00
# ℹ️ ACT101_12 had no preferred room → Assigned: 110
# ✅ ACT101_13 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ℹ️ ACT101_13 had no preferred room → Assigned: 223
# ✅ ACT101_13 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ℹ️ ACT101_13 had no preferred room → Assigned: 223
# ✅ ACT201_1 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ ACT201_1 had no preferred room → Assigned: LB-10 (Fluid Mechanics Lab)
# ✅ ACT201_1 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ ACT201_1 had no preferred room → Assigned: LB-10 (Fluid Mechanics Lab)
# ❌ ACT201_2 did NOT get preferred slot → Time: 01:30:00–03:00:00 ≠ 04:50:00–06:20:00
# ℹ️ ACT201_2 had no preferred room → Assigned: 107
# ❌ ACT201_2 did NOT get preferred slot → Time: 01:30:00–03:00:00 ≠ 08:30:00–10:00:00
# ℹ️ ACT201_2 had no preferred room → Assigned: 107
# ✅ ACT201_3 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT201_3 had no preferred room → Assigned: 107
# ✅ ACT201_3 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT201_3 had no preferred room → Assigned: 107
# ❌ ACT201_4 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 03:10:00–04:40:00
# ℹ️ ACT201_4 had no preferred room → Assigned: 107
# ❌ ACT201_4 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 03:10:00–04:40:00
# ℹ️ ACT201_4 had no preferred room → Assigned: 107
# ❌ ACT201_5 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ℹ️ ACT201_5 had no preferred room → Assigned: 110
# ❌ ACT201_5 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ℹ️ ACT201_5 had no preferred room → Assigned: 110
# ❌ ACT201_6 did NOT get preferred slot → Time: 08:30:00–10:00:00 ≠ 06:30:00–08:00:00
# ℹ️ ACT201_6 had no preferred room → Assigned: 431 (Multi Media and Image Processing Lab)
# ✅ ACT201_6 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ ACT201_6 had no preferred room → Assigned: 431 (Multi Media and Image Processing Lab)
# ✅ ACT201_7 got preferred slot → Time: 11:50:00–01:20:00 = 11:50:00–01:20:00
# ℹ️ ACT201_7 had no preferred room → Assigned: 434 (Big Data Analytics Lab)
# ❌ ACT201_7 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 06:30:00–08:00:00
# ℹ️ ACT201_7 had no preferred room → Assigned: 434 (Big Data Analytics Lab)
# ✅ ACT201_8 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ℹ️ ACT201_8 had no preferred room → Assigned: 363 (Survey Lab)
# ✅ ACT201_8 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ℹ️ ACT201_8 had no preferred room → Assigned: 363 (Survey Lab)
# ✅ ACT411_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ✅ ACT411_1 got preferred room → 336 = 336
# ✅ ACT411_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ✅ ACT411_1 got preferred room → 336 = 336
# ❌ ACT411_2 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ℹ️ ACT411_2 had no preferred room → Assigned: 113
# ❌ ACT411_2 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ℹ️ ACT411_2 had no preferred room → Assigned: 113
# ✅ ACT421_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT421_1 had no preferred room → Assigned: 227
# ✅ ACT421_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ ACT421_1 had no preferred room → Assigned: 227
# ❌ ACT421_2 did NOT get preferred slot → Time: 03:10:00–04:40:00 ≠ 06:30:00–08:00:00
# ℹ️ ACT421_2 had no preferred room → Assigned: 109
# ❌ ACT421_2 did NOT get preferred slot → Time: 03:10:00–04:40:00 ≠ 06:30:00–08:00:00
# ℹ️ ACT421_2 had no preferred room → Assigned: 109
# ❌ ACT425_1 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 04:50:00–06:20:00
# ℹ️ ACT425_1 had no preferred room → Assigned: 221
# ❌ ACT425_1 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 04:50:00–06:20:00
# ℹ️ ACT425_1 had no preferred room → Assigned: 221
# ❌ ACT441_1 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 03:10:00–04:40:00
# ✅ ACT441_1 got preferred room → 429 = 429
# ❌ ACT441_1 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 03:10:00–04:40:00
# ✅ ACT441_1 got preferred room → 429 = 429
# ❌ ACT441_2 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ✅ ACT441_2 got preferred room → 429 = 429
# ❌ ACT441_2 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ✅ ACT441_2 got preferred room → 429 = 429
# ❌ ACT442_1 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 03:10:00–04:40:00
# ✅ ACT442_1 got preferred room → 336 = 336
# ❌ ACT442_1 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 03:10:00–04:40:00
# ✅ ACT442_1 got preferred room → 336 = 336
# ✅ ACT447_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ✅ ACT447_1 got preferred room → 336 = 336
# ✅ ACT447_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ✅ ACT447_1 got preferred room → 336 = 336
# ✅ ACT478_1 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ✅ ACT478_1 got preferred room → 429 = 429
# ✅ ACT478_1 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ✅ ACT478_1 got preferred room → 429 = 429
# ❌ BUS231_1 did NOT get preferred slot → Time: 01:30:00–03:00:00 ≠ 03:10:00–04:40:00
# ℹ️ BUS231_1 had no preferred room → Assigned: 102
# ❌ BUS231_1 did NOT get preferred slot → Time: 01:30:00–03:00:00 ≠ 03:10:00–04:40:00
# ℹ️ BUS231_1 had no preferred room → Assigned: 102
# ❌ BUS231_2 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 06:30:00–08:00:00
# ℹ️ BUS231_2 had no preferred room → Assigned: 107
# ❌ BUS231_2 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 04:50:00–06:20:00
# ℹ️ BUS231_2 had no preferred room → Assigned: 107
# ❌ BUS231_3 did NOT get preferred slot → Time: 03:10:00–04:40:00 ≠ 01:30:00–03:00:00
# ℹ️ BUS231_3 had no preferred room → Assigned: 108
# ❌ BUS231_3 did NOT get preferred slot → Time: 03:10:00–04:40:00 ≠ 01:30:00–03:00:00
# ℹ️ BUS231_3 had no preferred room → Assigned: 108
# ✅ BUS231_4 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ BUS231_4 had no preferred room → Assigned: 111
# ✅ BUS231_4 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ BUS231_4 had no preferred room → Assigned: 111
# ❌ BUS231_5 did NOT get preferred slot → Time: 08:30:00–10:00:00 ≠ 04:50:00–06:20:00
# ℹ️ BUS231_5 had no preferred room → Assigned: 112
# ❌ BUS231_5 did NOT get preferred slot → Time: 08:30:00–10:00:00 ≠ 03:10:00–04:40:00
# ℹ️ BUS231_5 had no preferred room → Assigned: 112
# ❌ BUS231_6 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 03:10:00–04:40:00
# ℹ️ BUS231_6 had no preferred room → Assigned: 112
# ❌ BUS231_6 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ℹ️ BUS231_6 had no preferred room → Assigned: 112
# ✅ BUS231_7 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ BUS231_7 had no preferred room → Assigned: 431 (Multi Media and Image Processing Lab)
# ❌ BUS231_7 did NOT get preferred slot → Time: 08:30:00–10:00:00 ≠ 06:30:00–08:00:00
# ℹ️ BUS231_7 had no preferred room → Assigned: 431 (Multi Media and Image Processing Lab)
# ❌ BUS231_8 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 01:30:00–03:00:00
# ℹ️ BUS231_8 had no preferred room → Assigned: LB-10A (Transportation Lab)
# ✅ BUS231_8 got preferred slot → Time: 11:50:00–01:20:00 = 11:50:00–01:20:00
# ℹ️ BUS231_8 had no preferred room → Assigned: LB-10A (Transportation Lab)
# ✅ BUS231_9 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ BUS231_9 had no preferred room → Assigned: 114
# ✅ BUS231_9 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ BUS231_9 had no preferred room → Assigned: 114
# ✅ BUS361_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ BUS361_1 had no preferred room → Assigned: 115
# ✅ BUS361_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ BUS361_1 had no preferred room → Assigned: 115
# ✅ BUS361_2 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ BUS361_2 had no preferred room → Assigned: LB-10A (Transportation Lab)
# ✅ BUS361_2 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ BUS361_2 had no preferred room → Assigned: LB-10A (Transportation Lab)
# ✅ BUS361_3 got preferred slot → Time: 11:50:00–01:20:00 = 11:50:00–01:20:00
# ℹ️ BUS361_3 had no preferred room → Assigned: 222
# ✅ BUS361_3 got preferred slot → Time: 11:50:00–01:20:00 = 11:50:00–01:20:00
# ℹ️ BUS361_3 had no preferred room → Assigned: 222
# ✅ BUS361_4 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ BUS361_4 had no preferred room → Assigned: LB-10A (Transportation Lab)
# ✅ BUS361_4 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ BUS361_4 had no preferred room → Assigned: LB-10A (Transportation Lab)
# ✅ BUS361_5 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ BUS361_5 had no preferred room → Assigned: 435 (Virtual Reality and Augmented Reality Lab)
# ✅ BUS361_5 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ BUS361_5 had no preferred room → Assigned: 435 (Virtual Reality and Augmented Reality Lab)
# ✅ BUS361_6 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ BUS361_6 had no preferred room → Assigned: 212
# ✅ BUS361_6 got preferred slot → Time: 08:30:00–10:00:00 = 08:30:00–10:00:00
# ℹ️ BUS361_6 had no preferred room → Assigned: 212
# ✅ BUS361_7 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ BUS361_7 had no preferred room → Assigned: AB1-202
# ✅ BUS361_7 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ BUS361_7 had no preferred room → Assigned: AB1-202
# ❌ CE100_2 did NOT get preferred slot → Time: 01:30:00–03:30:00 ≠ 03:10:00–04:40:00
# ✅ CE100_2 got preferred room → 352 (Drawing Lab) = 352 (Drawing Lab)
# ❌ CE100_3 did NOT get preferred slot → Time: 10:10:00–12:10:00 ≠ 01:30:00–03:00:00
# ✅ CE100_3 got preferred room → 352 (Drawing Lab) = 352 (Drawing Lab)
# ❌ CE101_1 did NOT get preferred slot → Time: 03:10:00–04:40:00 ≠ 01:30:00–03:00:00
# ❌ CE101_1 did NOT get preferred room → main campus ≠ 109
# ❌ CE101_1 did NOT get preferred slot → Time: 03:10:00–04:40:00 ≠ 01:30:00–03:00:00
# ❌ CE101_1 did NOT get preferred room → main campus ≠ 109
# ✅ CE101_2 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ℹ️ CE101_2 had no preferred room → Assigned: 220
# ✅ CE101_2 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ℹ️ CE101_2 had no preferred room → Assigned: 220
# ❌ CE102_1 did NOT get preferred slot → Time: 01:30:00–03:30:00 ≠ 10:10:00–11:40:00
# ❌ CE102_1 did NOT get preferred room → C. Lab ≠ 227
# ❌ CE102_2 did NOT get preferred slot → Time: 01:30:00–03:30:00 ≠ 11:50:00–01:20:00
# ❌ CE102_2 did NOT get preferred room → C. Lab ≠ 811 (GEB Lab-4)
# ❌ CE102_3 did NOT get preferred slot → Time: 01:30:00–03:30:00 ≠ 11:50:00–01:20:00
# ❌ CE102_3 did NOT get preferred room → C. Lab ≠ 217
# ❌ CE103_1 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 04:50:00–06:20:00
# ℹ️ CE103_1 had no preferred room → Assigned: 222
# ❌ CE103_1 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 04:50:00–06:20:00
# ℹ️ CE103_1 had no preferred room → Assigned: 222
# ❌ CE103_2 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 01:30:00–03:00:00
# ℹ️ CE103_2 had no preferred room → Assigned: 436 (Human-Computer Interaction Lab)
# ✅ CE103_2 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ CE103_2 had no preferred room → Assigned: 436 (Human-Computer Interaction Lab)
# ✅ CE103Lab_1 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ❌ CE103Lab_1 did NOT get preferred room → Any Classroom ≠ 363 (Survey Lab)
# ❌ CE103Lab_2 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 06:30:00–08:00:00
# ❌ CE103Lab_2 did NOT get preferred room → Any Classroom ≠ 372 (SEIP Lab)
# ❌ CE200_1 did NOT get preferred slot → Time: 08:00:00–11:00:00 ≠ 10:10:00–11:40:00
# ❌ CE200_1 did NOT get preferred room → Any Classroom for 3 Hrs ≠ 111
# ❌ CE201_1 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 08:30:00–10:00:00
# ℹ️ CE201_1 had no preferred room → Assigned: LB-10 (Fluid Mechanics Lab)
# ❌ CE201_1 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 03:10:00–04:40:00
# ℹ️ CE201_1 had no preferred room → Assigned: LB-10 (Fluid Mechanics Lab)
# ❌ CE201_2 did NOT get preferred slot → Time: 11:50:00–01:20:00 ≠ 06:30:00–08:00:00
# ℹ️ CE201_2 had no preferred room → Assigned: 436 (Human-Computer Interaction Lab)
# ✅ CE201_2 got preferred slot → Time: 11:50:00–01:20:00 = 11:50:00–01:20:00
# ℹ️ CE201_2 had no preferred room → Assigned: 436 (Human-Computer Interaction Lab)
# ✅ CE203_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ CE203_1 had no preferred room → Assigned: 220
# ✅ CE203_1 got preferred slot → Time: 01:30:00–03:00:00 = 01:30:00–03:00:00
# ℹ️ CE203_1 had no preferred room → Assigned: 220
# ❌ CE203_2 did NOT get preferred slot → Time: 01:30:00–03:00:00 ≠ 08:30:00–10:00:00
# ℹ️ CE203_2 had no preferred room → Assigned: 111
# ❌ CE203_2 did NOT get preferred slot → Time: 01:30:00–03:00:00 ≠ 08:30:00–10:00:00
# ℹ️ CE203_2 had no preferred room → Assigned: 111
# ❌ CE208_1 did NOT get preferred slot → Time: 10:10:00–01:10:00 ≠ 08:30:00–10:00:00
# ❌ CE208_1 did NOT get preferred room → Any Classroom for 3 Hrs ≠ 109
# ✅ CE211_1 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ CE211_1 had no preferred room → Assigned: 108
# ✅ CE211_1 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ CE211_1 had no preferred room → Assigned: 108
# ✅ CE211_2 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ CE211_2 had no preferred room → Assigned: AB1-202
# ✅ CE211_2 got preferred slot → Time: 10:10:00–11:40:00 = 10:10:00–11:40:00
# ℹ️ CE211_2 had no preferred room → Assigned: AB1-202
# ❌ CE211Lab_1 did NOT get preferred slot → Time: 10:10:00–01:10:00 ≠ 01:30:00–04:30:00
# ❌ CE211Lab_1 did NOT get preferred room → LB-14 (Strength of Material Lab)   ≠ 804 (GEB Lab-1)
# ❌ CE213_1 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 06:30:00–08:00:00
# ℹ️ CE213_1 had no preferred room → Assigned: 222
# ❌ CE213_1 did NOT get preferred slot → Time: 10:10:00–11:40:00 ≠ 06:30:00–08:00:00
# ℹ️ CE213_1 had no preferred room → Assigned: 222
# ✅ CE213_2 got preferred slot → Time: 04:50:00–06:20:00 = 04:50:00–06:20:00
# ℹ️ CE213_2 had no preferred room → Assigned: AB1-202
# ✅ CE213_2 got preferred slot → Time: 04:50:00–06:20:00 = 04:50:00–06:20:00
# ℹ️ CE213_2 had no preferred room → Assigned: AB1-202
# ❌ CE261_1 did NOT get preferred slot → Time: 01:30:00–03:00:00 ≠ 04:50:00–06:20:00
# ℹ️ CE261_1 had no preferred room → Assigned: 110
# ❌ CE261_1 did NOT get preferred slot → Time: 01:30:00–03:00:00 ≠ 03:10:00–04:40:00
# ℹ️ CE261_1 had no preferred room → Assigned: 110
# ✅ CE261_2 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ℹ️ CE261_2 had no preferred room → Assigned: AB1-202
# ✅ CE261_2 got preferred slot → Time: 03:10:00–04:40:00 = 03:10:00–04:40:00
# ℹ️ CE261_2 had no preferred room → Assigned: AB1-202
# 🧠 Total courses scheduled: 24
# 📚 Total slots used: 132
# 🏫 Room usage breakdown:
#  Room
# 107                                                12
# 110                                                10
# AB1-202                                            10
# 222                                                 8
# 431 (Multi Media and Image Processing Lab)          6
# 436 (Human-Computer Interaction Lab)                6
# 336                                                 6
# LB-10A (Transportation Lab)                         6
# 429                                                 6
# 109                                                 5
# 111                                                 5
# LB-10 (Fluid Mechanics Lab)                         4
# 112                                                 4
# 108                                                 4
# AB1-301                                             4
# 220                                                 4
# 363 (Survey Lab)                                    3
# 227                                                 3
# 221                                                 2
# 434 (Big Data Analytics Lab)                        2
# 223                                                 2
# 430                                                 2
# 113                                                 2
# 114                                                 2
# 102                                                 2
# 115                                                 2
# 435 (Virtual Reality and Augmented Reality Lab)     2
# 212                                                 2
# 352 (Drawing Lab)                                   2
# 811 (GEB Lab-4)                                     1
# 217                                                 1
# 372 (SEIP Lab)                                      1
# 804 (GEB Lab-1)                                     1
# Name: count, dtype: int64
# ✅ Output written to final_schedule_output.xlsx
#
# 📋 Soft Constraint Violations:
# ❌ Time fixed for ACT101_3 (Prof/Dean/Head) | Penalty: 100
# ❌ Basic time preference mismatch for ACT101_4 | Penalty: 20
# ❌ Basic time preference mismatch for ACT101_5 | Penalty: 20
# ❌ Basic time preference mismatch for ACT101_6 | Penalty: 20
# ❌ Basic time preference mismatch for ACT101_6 | Penalty: 20
# ❌ Basic time preference mismatch for ACT101_7 | Penalty: 20
# ❌ Basic time preference mismatch for ACT101_7 | Penalty: 20
# ❌ Basic time preference mismatch for ACT101_8 | Penalty: 20
# ❌ Basic time preference mismatch for ACT101_12 | Penalty: 20
# ❌ Basic time preference mismatch for ACT101_12 | Penalty: 20
# ❌ Time fixed for ACT201_4 (Prof/Dean/Head) | Penalty: 100
# ❌ Time fixed for ACT201_4 (Prof/Dean/Head) | Penalty: 100
# ❌ Basic time preference mismatch for ACT201_5 | Penalty: 20
# ❌ Basic time preference mismatch for ACT201_5 | Penalty: 20
# ❌ Basic time preference mismatch for ACT201_6 | Penalty: 20
# ❌ Basic time preference mismatch for ACT201_7 | Penalty: 20
# ❌ Basic time preference mismatch for ACT411_2 | Penalty: 20
# ❌ Basic time preference mismatch for ACT411_2 | Penalty: 20
# ❌ Basic time preference mismatch for ACT425_1 | Penalty: 20
# ❌ Basic time preference mismatch for ACT425_1 | Penalty: 20
# ❌ Time fixed for ACT441_1 (Prof/Dean/Head) | Penalty: 100
# ❌ Time fixed for ACT441_1 (Prof/Dean/Head) | Penalty: 100
# ❌ Time fixed for ACT441_2 (Prof/Dean/Head) | Penalty: 100
# ❌ Time fixed for ACT441_2 (Prof/Dean/Head) | Penalty: 100
# ❌ Time fixed for ACT442_1 (Prof/Dean/Head) | Penalty: 100
# ❌ Time fixed for ACT442_1 (Prof/Dean/Head) | Penalty: 100
# ❌ Basic time preference mismatch for BUS231_5 | Penalty: 20
# ❌ Basic time preference mismatch for BUS231_5 | Penalty: 20
# ❌ Basic time preference mismatch for BUS231_6 | Penalty: 20
# ❌ Basic time preference mismatch for BUS231_6 | Penalty: 20
# ❌ Basic time preference mismatch for BUS231_7 | Penalty: 20
# ❌ Basic time preference mismatch for BUS231_8 | Penalty: 20
# ❌ Basic time preference mismatch for CE102_3 | Penalty: 20
# ❌ Basic time preference mismatch for CE103_1 | Penalty: 20
# ❌ Basic time preference mismatch for CE103_1 | Penalty: 20
# ❌ Basic time preference mismatch for CE103_2 | Penalty: 20
# ❌ Basic time preference mismatch for CE103Lab_2 | Penalty: 20
# ❌ Basic time preference mismatch for CE201_2 | Penalty: 20
# ❌ Basic time preference mismatch for CE213_1 | Penalty: 20
# ❌ Basic time preference mismatch for CE213_1 | Penalty: 20
# 🔎 Total Violations: 40 out of 1492
